# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('test_v2.csv')

# %%
df.head()
# Out:
#    customer_ID  shopping_pt  record_type  day   time state  location  \
# 0     10000001            1            0    1  12:35    OK   10002.0
# 1     10000001            2            0    1  12:36    OK   10002.0
# 2     10000002            1            0    4  12:19    PA   10003.0
# 3     10000002            2            0    4  12:21    PA   10003.0
# 4     10000003            1            0    3  17:12    AR   10004.0
#
#    group_size  homeowner  car_age  ...  C_previous  duration_previous  A  B  \
# 0           1          0        9  ...         3.0                9.0  0  0
# 1           1          0        9  ...         3.0                9.0  2  1
# 2           1          1        7  ...         2.0               15.0  2  0
# 3           1          1        7  ...         2.0               15.0  2  0
# 4           1          0        4  ...         3.0                1.0  1  0
#
#    C  D  E  F  G  cost
# 0  1  1  0  0  4   543
# 1  1  3  1  3  2   611
# ...

# %%
df.describe().T
# Out:
#                       count          mean           std         min  \
# customer_ID        198856.0  1.007608e+07  44103.970222  10000001.0
# shopping_pt        198856.0  2.653966e+00      1.602248         1.0
# record_type        198856.0  0.000000e+00      0.000000         0.0
# day                198856.0  1.912359e+00      1.442332         0.0
# location           198178.0  1.232262e+04   1592.510709     10001.0
# group_size         198856.0  1.232424e+00      0.454229         1.0
# homeowner          198856.0  5.394959e-01      0.498439         0.0
# car_age            198856.0  8.098317e+00      5.746131         0.0
# risk_factor        123369.0  2.549352e+00      1.111686         1.0
# age_oldest         198856.0  4.579756e+01     17.443553        18.0
# age_youngest       198856.0  4.353649e+01     17.526266        16.0
# married_couple     198856.0  2.092922e-01      0.406804         0.0
# C_previous         189087.0  2.435070e+00      1.033821         1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198856 entries, 0 to 198855
# Data columns (total 25 columns):
# customer_ID          198856 non-null int64
# shopping_pt          198856 non-null int64
# record_type          198856 non-null int64
# day                  198856 non-null int64
# time                 198856 non-null object
# state                198856 non-null object
# location             198178 non-null float64
# group_size           198856 non-null int64
# homeowner            198856 non-null int64
# car_age              198856 non-null int64
# car_value            198117 non-null object
# risk_factor          123369 non-null float64
# age_oldest           198856 non-null int64
# age_youngest         198856 non-null int64
# married_couple       198856 non-null int64
# C_previous           189087 non-null float64
# duration_previous    189087 non-null float64
# A                    198856 non-null int64
# B                    198856 non-null int64
# ...

# %%
df['state'].unique()
# Out:
# array(['OK', 'PA', 'AR', 'WA', 'FL', 'KY', 'MO', 'NY', 'NV', 'OH', 'AL',
#        'NE', 'CO', 'TN', 'ME', 'UT', 'GA', 'CT', 'WI', 'OR', 'ID', 'NH',
#        'IA', 'WV', 'IN', 'MS', 'MD', 'DE', 'KS', 'NM', 'RI', 'WY', 'MT',
#        'SD', 'ND', 'DC'], dtype=object)

# %%
df['state'].unique().shape
# Out:
# (36,)

# %%
df['record_type'].describe()
# Out:
# count    198856.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# Name: record_type, dtype: float64

# %%
selection = []
count = 0
while (count< df.shape[0]-1):
    if not int(df['customer_ID'][count]) == int(df['customer_ID'][count+1]):
        a_sel = str(df['A'][count])
        b_sel = str(df['B'][count])
        c_sel = str(df['C'][count])
        d_sel = str(df['D'][count])
        e_sel = str(df['E'][count])
        f_sel = str(df['F'][count])
        g_sel = str(df['G'][count])
        choice = str(a_sel +b_sel +c_sel +d_sel +e_sel +f_sel +g_sel)
        selection.append(choice)
    count+=1

# %%
a_sel = str(df['A'][count])
b_sel = str(df['B'][198855])
c_sel = str(df['C'][198855])
d_sel = str(df['D'][198855])
e_sel = str(df['E'][198855])
f_sel = str(df['F'][198855])
g_sel = str(df['G'][198855])
choice = a_sel +b_sel +c_sel +d_sel +e_sel +f_sel +g_sel
selection.append(choice)

# %%
cust_ID_list = df['customer_ID'].unique()
np.count_nonzero(cust_ID_list)
# Out:
# 55716

# %%
np.count_nonzero(selection)
# Out:
# 55716

# %%
submission = pd.DataFrame(
    {'customer_ID': cust_ID_list,
     'plan_select': selection
    })

# %%
submission.to_csv("initial_submit.csv")

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55716 entries, 0 to 55715
# Data columns (total 2 columns):
# customer_ID    55716 non-null int64
# plan_select    55716 non-null object
# dtypes: int64(1), object(1)
# memory usage: 870.6+ KB
