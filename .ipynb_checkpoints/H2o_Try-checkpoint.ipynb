# %%
import pandas as pd

# %%
data = pd.read_csv('Data/train.csv')

# %%
data.head()
# Out:
#    customer_ID  shopping_pt  record_type  day   time state  location  \
# 0     10000000            1            0    0  08:35    IN     10001
# 1     10000000            2            0    0  08:38    IN     10001
# 2     10000000            3            0    0  08:38    IN     10001
# 3     10000000            4            0    0  08:39    IN     10001
# 4     10000000            5            0    0  11:55    IN     10001
#
#    group_size  homeowner  car_age  ...  C_previous  duration_previous  A  B  \
# 0           2          0        2  ...         1.0                2.0  1  0
# 1           2          0        2  ...         1.0                2.0  1  0
# 2           2          0        2  ...         1.0                2.0  1  0
# 3           2          0        2  ...         1.0                2.0  1  0
# 4           2          0        2  ...         1.0                2.0  1  0
#
#    C  D  E  F  G  cost
# 0  2  2  1  2  2   633
# 1  2  2  1  2  1   630
# ...

# %%
data.shape
# Out:
# (665249, 25)

# %%
data.columns
# Out:
# Index(['customer_ID', 'shopping_pt', 'record_type', 'day', 'time', 'state',
#        'location', 'group_size', 'homeowner', 'car_age', 'car_value',
#        'risk_factor', 'age_oldest', 'age_youngest', 'married_couple',
#        'C_previous', 'duration_previous', 'A', 'B', 'C', 'D', 'E', 'F', 'G',
#        'cost'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665249 entries, 0 to 665248
# Data columns (total 25 columns):
# customer_ID          665249 non-null int64
# shopping_pt          665249 non-null int64
# record_type          665249 non-null int64
# day                  665249 non-null int64
# time                 665249 non-null object
# state                665249 non-null object
# location             665249 non-null int64
# group_size           665249 non-null int64
# homeowner            665249 non-null int64
# car_age              665249 non-null int64
# car_value            663718 non-null object
# risk_factor          424831 non-null float64
# age_oldest           665249 non-null int64
# age_youngest         665249 non-null int64
# married_couple       665249 non-null int64
# C_previous           646538 non-null float64
# duration_previous    646538 non-null float64
# A                    665249 non-null int64
# B                    665249 non-null int64
# ...

# %%
data.describe()
# Out:
#         customer_ID    shopping_pt    record_type            day  \
# count  6.652490e+05  665249.000000  665249.000000  665249.000000
# mean   1.007655e+07       4.219966       0.145824       1.969429
# std    4.404978e+04       2.394369       0.352930       1.453470
# min    1.000000e+07       1.000000       0.000000       0.000000
# 25%    1.003852e+07       2.000000       0.000000       1.000000
# 50%    1.007640e+07       4.000000       0.000000       2.000000
# 75%    1.011470e+07       6.000000       0.000000       3.000000
# max    1.015272e+07      13.000000       1.000000       6.000000
#
#             location     group_size      homeowner        car_age  \
# count  665249.000000  665249.000000  665249.000000  665249.000000
# mean    12271.543022       1.234784       0.536229       8.139437
# std      1564.789415       0.461036       0.498686       5.764598
# min     10001.000000       1.000000       0.000000       0.000000
# ...

# %% [markdown]
# ### Columns:
# customer_ID - A unique identifier for the customer
#
# shopping_pt - Unique identifier for the shopping point of a given customer
#
# record_type - 0=shopping point, 1=purchase point
#
# day - Day of the week (0-6, 0=Monday)
#
# time - Time of day (HH:MM)
#
# state - State where shopping point occurred
#
# location - Location ID where shopping point occurred
#
# group_size - How many people will be covered under the policy (1, 2, 3 or 4)
#
# homeowner - Whether the customer owns a home or not (0=no, 1=yes)
#
# car_age - Age of the customer’s car
#
# car_value - How valuable was the customer’s car when new
#
# risk_factor - An ordinal assessment of how risky the customer is (1, 2, 3, 4)
#
# age_oldest - Age of the oldest person in customer's group
#
# age_youngest - Age of the youngest person in customer’s group
#
# married_couple - Does the customer group contain a married couple (0=no, 1=yes)
#
# C_previous - What the customer formerly had or currently has for product option C (0=nothing, 1, 2, 3,4)
#
# duration_previous -  how long (in years) the customer was covered by their previous issuer
#
# A,B,C,D,E,F,G - the coverage options
#
# cost - cost of the quoted coverage options
#
# #### Coverage Options Description:
#
# ![product_options.png](attachment:product_options.png)

# %%
import missingno as msno

# %%
msno.matrix(data)

# %%
data.isnull().sum().sum()
# Out:
# 279371

# %%
data.risk_factor
# Out:
# 0         3.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         3.0
# 5         3.0
# 6         3.0
# 7         3.0
# 8         3.0
# 9         4.0
# 10        4.0
# 11        4.0
# 12        4.0
# 13        4.0
# 14        4.0
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        3.0
# 24        3.0
# 25        3.0
# 26        3.0
# 27        3.0
# 28        3.0
# 29        3.0
#          ...
# 665219    2.0
# 665220    2.0
# 665221    2.0
# 665222    2.0
# 665223    2.0
# 665224    2.0
# 665225    2.0
# 665226    4.0
# 665227    4.0
# 665228    4.0
# 665229    4.0
# 665230    4.0
# 665231    4.0
# 665232    4.0
# 665233    4.0
# 665234    NaN
# 665235    NaN
# 665236    NaN
# 665237    NaN
# 665238    NaN
# 665239    NaN
# 665240    2.0
# 665241    2.0
# 665242    2.0
# 665243    NaN
# 665244    NaN
# 665245    NaN
# 665246    NaN
# 665247    NaN
# 665248    NaN
# ...

# %%
data['risk_factor'].isnull().sum().sum()
# Out:
# 240418

# %%
data['risk_factor'].mean(axis=0)
# Out:
# 2.563996036070814

# %%
data['risk_factor'].value_counts()
# Out:
# 3.0    117571
# 4.0    110754
# 1.0     99476
# 2.0     97030
# Name: risk_factor, dtype: int64

# %%
data['state'].unique().shape[0]
# Out:
# 36

# %%
data.car_value
# Out:
# 0         g
# 1         g
# 2         g
# 3         g
# 4         g
# 5         g
# 6         g
# 7         g
# 8         g
# 9         e
# 10        e
# 11        e
# 12        e
# 13        e
# 14        e
# 15        c
# 16        c
# 17        c
# 18        c
# 19        c
# 20        c
# 21        c
# 22        c
# 23        d
# 24        d
# 25        d
# 26        d
# 27        d
# 28        d
# 29        d
#          ..
# 665219    e
# 665220    e
# 665221    e
# 665222    e
# 665223    e
# 665224    e
# 665225    e
# 665226    g
# 665227    g
# 665228    g
# 665229    g
# 665230    g
# 665231    g
# 665232    g
# 665233    g
# 665234    e
# 665235    e
# 665236    e
# 665237    e
# 665238    e
# 665239    e
# 665240    f
# 665241    f
# 665242    g
# 665243    e
# 665244    e
# 665245    e
# 665246    e
# 665247    e
# 665248    d
# Name: car_value, Length: 665249, dtype: object

# %%
data_h2o = pd.read_csv('Data/train.csv')

# %%
cols = ['A', 'B', 'C','D', 'E', 'F', 'G']

# %%
for i in cols:
    data_h2o[i] = data[i].astype(str)

# %%
data_h2o["Policy"] = data_h2o[cols].apply(lambda x: ''.join(x), axis=1)

# %%
data_h2o.Policy
# Out:
# 0         1022122
# 1         1022121
# 2         1022121
# 3         1022121
# 4         1022121
# 5         1022121
# 6         1022121
# 7         1022121
# 8         1022121
# 9         1133102
# 10        1133102
# 11        1133102
# 12        0032002
# 13        0032002
# 14        0032002
# 15        0023003
# 16        0023001
# 17        0011001
# 18        0011001
# 19        0011001
# 20        0022001
# 21        0022001
# 22        0012001
# 23        1132123
# 24        1132123
# 25        1132113
# 26        1132113
# 27        1133022
# 28        2111022
# 29        1111022
#            ...
# 665219    2143034
# 665220    1143124
# 665221    1143124
# 665222    1143124
# 665223    1143124
# 665224    1143124
# 665225    1143124
# 665226    1012122
# 665227    1012123
# 665228    1012023
# 665229    1012023
# 665230    1012023
# 665231    1012023
# 665232    1012023
# 665233    1012023
# 665234    1133101
# 665235    1012101
# 665236    1012101
# 665237    1012102
# ...

# %%
data_h2o["Policy"] = data_h2o["Policy"].astype(int)

# %%
data_h2o.Policy
# Out:
# 0         1022122
# 1         1022121
# 2         1022121
# 3         1022121
# 4         1022121
# 5         1022121
# 6         1022121
# 7         1022121
# 8         1022121
# 9         1133102
# 10        1133102
# 11        1133102
# 12          32002
# 13          32002
# 14          32002
# 15          23003
# 16          23001
# 17          11001
# 18          11001
# 19          11001
# 20          22001
# 21          22001
# 22          12001
# 23        1132123
# 24        1132123
# 25        1132113
# 26        1132113
# 27        1133022
# 28        2111022
# 29        1111022
#            ...
# 665219    2143034
# 665220    1143124
# 665221    1143124
# 665222    1143124
# 665223    1143124
# 665224    1143124
# 665225    1143124
# 665226    1012122
# 665227    1012123
# 665228    1012023
# 665229    1012023
# 665230    1012023
# 665231    1012023
# 665232    1012023
# 665233    1012023
# 665234    1133101
# 665235    1012101
# 665236    1012101
# 665237    1012102
# ...

# %%
data_h2o.head(20)
# Out:
#     customer_ID  shopping_pt  record_type  day   time state  location  \
# 0      10000000            1            0    0  08:35    IN     10001
# 1      10000000            2            0    0  08:38    IN     10001
# 2      10000000            3            0    0  08:38    IN     10001
# 3      10000000            4            0    0  08:39    IN     10001
# 4      10000000            5            0    0  11:55    IN     10001
# 5      10000000            6            0    0  11:57    IN     10001
# 6      10000000            7            0    0  11:58    IN     10001
# 7      10000000            8            0    0  12:03    IN     10001
# 8      10000000            9            1    0  12:07    IN     10001
# 9      10000005            1            0    3  08:56    NY     10006
# 10     10000005            2            0    3  08:56    NY     10006
# 11     10000005            3            0    3  08:57    NY     10006
# ...

# %%
data_h2o.drop(cols, axis=1)
# Out:
#         customer_ID  shopping_pt  record_type  day   time state  location  \
# 0          10000000            1            0    0  08:35    IN     10001
# 1          10000000            2            0    0  08:38    IN     10001
# 2          10000000            3            0    0  08:38    IN     10001
# 3          10000000            4            0    0  08:39    IN     10001
# 4          10000000            5            0    0  11:55    IN     10001
# 5          10000000            6            0    0  11:57    IN     10001
# 6          10000000            7            0    0  11:58    IN     10001
# 7          10000000            8            0    0  12:03    IN     10001
# 8          10000000            9            1    0  12:07    IN     10001
# 9          10000005            1            0    3  08:56    NY     10006
# 10         10000005            2            0    3  08:56    NY     10006
# 11         10000005            3            0    3  08:57    NY     10006
# ...

# %%
import h2o
from h2o.automl import H2OAutoML

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 25.181-b13, mixed mode)
#   Starting server from C:\Users\achar\Anaconda3\lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\achar\AppData\Local\Temp\tmpcm1a7378
#   JVM stdout: C:\Users\achar\AppData\Local\Temp\tmpcm1a7378\h2o_achar_started_from_python.out
#   JVM stderr: C:\Users\achar\AppData\Local\Temp\tmpcm1a7378\h2o_achar_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321... successful.
# --------------------------  -------------------------------
# H2O cluster uptime:         04 secs
# H2O cluster timezone:       America/New_York
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.22.0.2
# H2O cluster version age:    19 days
# H2O cluster name:           H2O_from_python_achar_ay2pzt
# ...

# %%
df= h2o.H2OFrame(data_h2o)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
splits = df.split_frame(ratios=[0.7, 0.15], seed=1)

# %%
train = splits[0]
valid = splits[1]
test = splits[2]

# %%
x = train.columns
y= 'record_type'

# %%
x.remove(y)

# %%
aml = H2OAutoML()

# %%
aml.train(x = x, y = y, training_frame = train, leaderboard_frame= test, validation_frame=valid)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
lb = aml.leaderboard

# %%
lb
# Out:
# <table>
# <thead>
# <tr><th>model_id                                           </th><th style="text-align: right;">  mean_residual_deviance</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">      mse</th><th style="text-align: right;">     mae</th><th style="text-align: right;">   rmsle</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_AutoML_20181211_144216   </td><td style="text-align: right;">               0.0952227</td><td style="text-align: right;">0.308582</td><td style="text-align: right;">0.0952227</td><td style="text-align: right;">0.189582</td><td style="text-align: right;">0.216164</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_AutoML_20181211_144216</td><td style="text-align: right;">               0.0952262</td><td style="text-align: right;">0.308587</td><td style="text-align: right;">0.0952262</td><td style="text-align: right;">0.189856</td><td style="text-align: right;">0.216154</td></tr>
# ...

# %%
leader = aml.leader

# %%
import matplotlib as plt
# %matplotlib inline

leader.varimp_plot
# Out:
# Model Details
# ...
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_AutoML_20181211_144216
# No model summary for this model
#
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.08524798294191452
# RMSE: 0.29197257224252166
# MAE: 0.17901957928871556
# RMSLE: 0.2038501772918423
# R^2: 0.31603039882596284
# Mean Residual Deviance: 0.08524798294191452
# Null degrees of freedom: 465957
# Residual degrees of freedom: 465947
# Null deviance: 58075.65068312474
# Residual deviance: 39721.979635648604
# AIC: 175078.0103251739
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on validation data. **
#
# MSE: 0.09388643783935162
# RMSE: 0.3064089389024929
# MAE: 0.18817846735143837
# RMSLE: 0.214857272719323
# R^2: 0.24095336709290882
# Mean Residual Deviance: 0.09388643783935162
# Null degrees of freedom: 99661
# Residual degrees of freedom: 99651
# Null deviance: 12327.365126512761
# ...

# %%
aml.leader.varimp_plot()
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-8da21ee1bfa5> in <module>()
# ----> 1 aml.leader.varimp_plot()
#
# ~\Anaconda3\lib\site-packages\h2o\model\model_base.py in varimp_plot(self, num_of_features, server)
#    1057         importances = self.varimp(use_pandas=False)
#    1058         # features labels correspond to the first value of each tuple in the importances list
# -> 1059         feature_labels = [tup[0] for tup in importances]
#    1060         # relative importances correspond to the first value of each tuple in the importances list
#    1061         scaled_importances = [tup[2] for tup in importances]
#
# TypeError: 'NoneType' object is not iterable

# %%
leader

# %%
data_test = pd.read_csv('Data/test_v2.csv')

# %%
for i in cols:
    data_test[i] = data_test[i].astype(str)

# %%
data_test["Policy"] = data_test[cols].apply(lambda x: ''.join(x), axis=1)

# %%
data_test["Policy"] = data_test["Policy"].astype(int)

# %%
data_test.drop(cols, axis=1)
# Out:
#         customer_ID  shopping_pt  record_type  day   time state  location  \
# 0          10000001            1            0    1  12:35    OK   10002.0
# 1          10000001            2            0    1  12:36    OK   10002.0
# 2          10000002            1            0    4  12:19    PA   10003.0
# 3          10000002            2            0    4  12:21    PA   10003.0
# 4          10000003            1            0    3  17:12    AR   10004.0
# 5          10000003            2            0    3  17:12    AR   10004.0
# 6          10000003            3            0    3  17:13    AR   10004.0
# 7          10000004            1            0    1  12:39    OK   10005.0
# 8          10000004            2            0    1  12:42    OK   10005.0
# 9          10000004            3            0    1  12:43    OK   10005.0
# 10         10000004            4            0    1  12:44    OK   10005.0
# 11         10000004            5            0    1  12:53    OK   10005.0
# ...

# %%
df_test = h2o.H2OFrame(data_test)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
h2o_preds = aml.predict(test_data = df_test)
# Out:
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# C:\Users\achar\Anaconda3\lib\site-packages\h2o\job.py:69: UserWarning: Test/Validation dataset column 'time' has levels not trained on: [00:02, 00:28, 00:57, 01:04, 01:09, 01:10, 01:11, 01:40, 01:41, 02:09, 02:11, 03:44, 03:45, 03:48, 04:57, 04:59, 06:07, 06:21, 23:57]
#   warnings.warn(w)

# %%
sub = df_test.cbind(h2o_preds)
sub = sub[['customer_ID', 'Policy', 'predict']]
sub.set_names(['customer_ID','Policy', 'record_type' ])
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  customer_ID</th><th style="text-align: right;">         Policy</th><th style="text-align: right;">  record_type</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        1e+07</td><td style="text-align: right;">11004          </td><td style="text-align: right;">  -0.0162301 </td></tr>
# <tr><td style="text-align: right;">        1e+07</td><td style="text-align: right;">    2.11313e+06</td><td style="text-align: right;">   0.00287063</td></tr>
# <tr><td style="text-align: right;">        1e+07</td><td style="text-align: right;">    2.02312e+06</td><td style="text-align: right;">  -0.00371447</td></tr>
# <tr><td style="text-align: right;">        1e+07</td><td style="text-align: right;">    2.02312e+06</td><td style="text-align: right;">   0.00777398</td></tr>
# ...

# %%
import os
h2o.export_file(sub[['customer_ID','Policy']],os.getcwd()+'\\'+'initial_Submission1.csv')
# Out:
# Export File progress: |███████████████████████████████████████████████████| 100%

# %%
submit_df = pd.read_csv('initial_Submission1.csv')

# %%
submit_df.head()
# Out:
#    customer_ID   Policy
# 0     10000001    11004
# 1     10000001  2113132
# 2     10000002  2023122
# 3     10000002  2023122
# 4     10000003  1011022

# %%
selection = []
count = 0
while (count< submit_df.shape[0]-1):
    if not int(submit_df['customer_ID'][count]) == int(submit_df['customer_ID'][count+1]):
        selection.append(submit_df['Policy'][count])
    count+=1

# %%
import numpy as np
cust_ID_list = submit_df['customer_ID'].unique()
np.count_nonzero(cust_ID_list)
# Out:
# 55716

# %%
np.count_nonzero(selection)
# Out:
# 55716

# %%
selection.append(submit_df['Policy'][count])

# %%
submission = pd.DataFrame(
    {'customer_ID': cust_ID_list,
     'plan_select': selection
    })

# %%
submission.to_csv("initial_submit.csv")

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55716 entries, 0 to 55715
# Data columns (total 2 columns):
# customer_ID    55716 non-null int64
# plan_select    55716 non-null int64
# dtypes: int64(2)
# memory usage: 870.6 KB
